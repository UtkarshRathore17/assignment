# %%
"""
Q1
Custom exceptions are used when you want to create an exception that is specific to your program or 
application. When creating a custom exception, it is important to use the Exception class as the base class.
This is because the Exception class provides the basic functionality that all exceptions need, such as a
message to describe the exception and a stack trace that shows where the exception occurred.
"""
# Out:
# '\nQ1\nCustom exceptions are used when you want to create an exception that is specific to your program or \napplication. When creating a custom exception, it is important to use the Exception class as the base class.\nThis is because the Exception class provides the basic functionality that all exceptions need, such as a\nmessage to describe the exception and a stack trace that shows where the exception occurred.\n'

# %%
"""
Q2
def print_exception_hierarchy(exc_cls, indent=0):
    print(' ' * indent + str(exc_cls.__name__))
    for sub_exc_cls in exc_cls.__subclasses__():
        print_exception_hierarchy(sub_exc_cls, indent + 2)

print_exception_hierarchy(BaseException)"""
# Out:
# BaseException
#   Exception
#     TypeError
#       FloatOperation
#       MultipartConversionError
#     StopAsyncIteration
#     StopIteration
#     ImportError
#       ModuleNotFoundError
#       ZipImportError
#     OSError
#       ConnectionError
#         BrokenPipeError
#         ConnectionAbortedError
#         ConnectionRefusedError
#         ConnectionResetError
#           RemoteDisconnected
#       BlockingIOError
#       ChildProcessError
#       FileExistsError
#       FileNotFoundError
#       IsADirectoryError
#       NotADirectoryError
#       InterruptedError
#         InterruptedSystemCall
#       PermissionError
#       ProcessLookupError
#       TimeoutError
#       UnsupportedOperation
#       itimer_error
#       herror
#       gaierror
#       SSLError
#         SSLCertVerificationError
#         SSLZeroReturnError
#         SSLWantWriteError
#         SSLWantReadError
#         SSLSyscallError
#         SSLEOFError
#       Error
#         SameFileError
# ...

# %%
"""
Q3
The ArithmeticError class in Python is the base class for all exceptions that occur during arithmetic
operations.
Some of the common exceptions that are derived from the ArithmeticError class are:
ZeroDivisionError: This exception is raised when you try to divide a number by zero.
10/0
Traceback (most recent call last):
  File "<stdin>", line 1, in <module>
ZeroDivisionError: division by zero
OverflowError: This exception is raised when a calculation exceeds the maximum limit of a numeric type.
10 ** 1000
Traceback (most recent call last):
  File "<stdin>", line 1, in <module>
OverflowError: (34, 'Numerical result out of range')
"""
# Out:
# '\nQ3\nThe ArithmeticError class in Python is the base class for all exceptions that occur during arithmetic\noperations.\nSome of the common exceptions that are derived from the ArithmeticError class are:\nZeroDivisionError: This exception is raised when you try to divide a number by zero.\n10/0\nTraceback (most recent call last):\n  File "<stdin>", line 1, in <module>\nZeroDivisionError: division by zero\nOverflowError: This exception is raised when a calculation exceeds the maximum limit of a numeric type.\n10 ** 1000\nTraceback (most recent call last):\n  File "<stdin>", line 1, in <module>\nOverflowError: (34, \'Numerical result out of range\')\n'

# %%
"""Q4
 the LookupError class is the base class for all exceptions that occur when an index or key is not found in a
 sequence or mapping. It is a subclass of the Exception class and is itself a subclass of the BaseException 
 class. The LookupError class is commonly used when you want to catch exceptions that occur due to missing
 keys or indices.
Two common exceptions that are derived from the LookupError class are KeyError and IndexError.
KeyError is raised when you try to access a dictionary key that does not exist.
 my_dict = {'a': 1, 'b': 2, 'c': 3}
 my_dict['d']
Traceback (most recent call last):
  File "<stdin>", line 1, in <module>
KeyError: 'd'
IndexError is raised when you try to access a list or tuple index that does not exist. For example:
my_list = [1, 2, 3]
my_list[3]
Traceback (most recent call last):
  File "<stdin>", line 1, in <module>
IndexError: list index out of range
"""
# Out:
# 'Q4\n the LookupError class is the base class for all exceptions that occur when an index or key is not found in a\n sequence or mapping. It is a subclass of the Exception class and is itself a subclass of the BaseException \n class. The LookupError class is commonly used when you want to catch exceptions that occur due to missing\n keys or indices.\nTwo common exceptions that are derived from the LookupError class are KeyError and IndexError.\nKeyError is raised when you try to access a dictionary key that does not exist.\n my_dict = {\'a\': 1, \'b\': 2, \'c\': 3}\n my_dict[\'d\']\nTraceback (most recent call last):\n  File "<stdin>", line 1, in <module>\nKeyError: \'d\'\nIndexError is raised when you try to access a list or tuple index that does not exist. For example:\nmy_list = [1, 2, 3]\nmy_list[3]\nTraceback (most recent call last):\n  File "<stdin>", line 1, in <module>\nIndexError: list index out of range\n'

# %%
"""
Q5
ImportError is an exception that is raised when an import statement fails to locate the module or the named 
attribute that is being imported. It is a subclass of the ImportError class and is itself a subclass of the
Exception class. This error can occur due to various reasons, such as the module is not installed, the module
is not in the search path, the module name is misspelled, or the module contains errors.
ModuleNotFoundError is a subclass of ImportError that is introduced in Python 3.6. It is raised when a module
could not be found during an import statement. It is more specific than ImportError, as it only applies to 
cases where the specified module does not exist."""
# Out:
# '\nQ5\nImportError is an exception that is raised when an import statement fails to locate the module or the named \nattribute that is being imported. It is a subclass of the ImportError class and is itself a subclass of the\nException class. This error can occur due to various reasons, such as the module is not installed, the module\nis not in the search path, the module name is misspelled, or the module contains errors.\nModuleNotFoundError is a subclass of ImportError that is introduced in Python 3.6. It is raised when a module\ncould not be found during an import statement. It is more specific than ImportError, as it only applies to \ncases where the specified module does not exist.'

# %%
"""Q6
